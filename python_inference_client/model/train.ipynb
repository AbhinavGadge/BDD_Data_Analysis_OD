# %%
# Author: Abhinav Narayan Gadge
# Email: abhigadge12@gmail.com

import os
from ultralytics import YOLO, RTDETR

# ------------------ Config ------------------ #
# Choose model: "yolov8n.pt", "yolov8m.pt", "yolo11m.pt", "rtdetr-l.pt"
MODEL = "yolov8n.pt"

# Dataset config (YAML file)
DATA_YAML = r"C:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\python_inference_client\bdd_data\data.yaml"

# Training save directory
PROJECT_DIR = "trainingPath"

# Training hyperparameters
EPOCHS = 50
PATIENCE = 10
SAVE_PERIOD = 5
LR0 = 0.001
# -------------------------------------------- #

# Initialize model
if "rtdetr" in MODEL.lower():
    model = RTDETR(MODEL)
    batch_size = 64  # RT-DETR requires smaller batch size
else:
    model = YOLO(MODEL)
    batch_size = 2   # YOLO can handle larger batch size

# Train model
results = model.train(
    data=DATA_YAML,
    epochs=EPOCHS,
    batch=batch_size,
    project=PROJECT_DIR,
    name=f"BDD_{MODEL.replace('.pt', '')}",
    exist_ok=False,
    device="cpu",       # Change to "cuda" for GPU
    resume=False,
    plots=True,
    patience=PATIENCE,
    degrees=360,
    scale=0.6,
    translate=0.4,
    fliplr=0.8,
    mixup=0.5,
    copy_paste=0.3,
    save_period=SAVE_PERIOD,
    optimizer="SGD",
    lr0=LR0
)

print("✅ Training completed. Results saved in:", os.path.join(PROJECT_DIR, f"BDD_{MODEL.replace('.pt', '')}"))
# Out:
# New https://pypi.org/project/ultralytics/8.3.193 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.191  Python-3.13.5 torch-2.8.0+cpu CPU (13th Gen Intel Core(TM) i7-1355U)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=2, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.3, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\python_inference_client\bdd_data\data.yaml, degrees=360, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.8, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.5, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=BDD_yolov8n2, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=trainingPath, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=trainingPath\BDD_yolov8n2, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.6, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.4, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753067  ultralytics.nn.modules.head.Detect           [9, [64, 128, 256]]
# Model summary: 129 layers, 3,012,603 parameters, 3,012,587 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 816.3470.8 MB/s, size: 62.1 KB)
# train: Scanning C:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\python_inference_client\bdd_data\train\labels.cache... 300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 260839.8it/s 0.0s.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 769.3377.8 MB/s, size: 53.3 KB)
# val: Scanning C:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\python_inference_client\bdd_data\val\labels.cache... 300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 223895.2it/s 0.0s.0s
# Plotting labels to trainingPath\BDD_yolov8n2\labels.jpg...
# optimizer: SGD(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to trainingPath\BDD_yolov8n2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      2.864      4.387      1.957         40        640: 100% ━━━━━━━━━━━━ 150/150 1.3it/s 1:540.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 2.8it/s 27.1s0.4ss
#                    all        300       5684    0.00621      0.116    0.00988    0.00551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      2.695      4.211      1.818         57        640: 100% ━━━━━━━━━━━━ 150/150 1.2it/s 2:040.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 2.6it/s 28.7s0.4ss
#                    all        300       5684     0.0095      0.241     0.0225      0.011
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      2.546      4.079      1.725        129        640: 100% ━━━━━━━━━━━━ 150/150 0.89it/s 2:491.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 1.6it/s 46.2s0.6ss
#                    all        300       5684    0.00814      0.248     0.0226    0.00961
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G

#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G      2.291      2.649      1.515         87        640: 100% ━━━━━━━━━━━━ 150/150 1.0it/s 2:27<1.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 88% ━━━━━━━━━━╸─ 66/75 1.4it/s 38.8s<6.4ss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 33
#      30     batch_size = 2   # YOLO can handle larger batch size
#      32 # Train model
# ---> 33 results = model.train(
#      34     data=DATA_YAML,
#      35     epochs=EPOCHS,
#      36     batch=batch_size,
#      37     project=PROJECT_DIR,
#      38     name=f"BDD_{MODEL.replace('.pt', '')}",
#      39     exist_ok=False,
#      40     device="cpu",       # Change to "cuda" for GPU
#      41     resume=False,
#      42     plots=True,
#      43     patience=PATIENCE,
#      44     degrees=360,
#      45     scale=0.6,
#      46     translate=0.4,
#      47     fliplr=0.8,
#      48     mixup=0.5,
#      49     copy_paste=0.3,
#      50     save_period=SAVE_PERIOD,
#      51     optimizer="SGD",
#      52     lr0=LR0
#      53 )
#      55 print("✅ Training completed. Results saved in:", os.path.join(PROJECT_DIR, f"BDD_{MODEL.replace('.pt', '')}"))
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\engine\model.py:801, in Model.train(self, trainer, **kwargs)
#     798     self.model = self.trainer.model
#     800 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 801 self.trainer.train()
#     802 # Update model and cfg after training
#     803 if RANK in {-1, 0}:
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\engine\trainer.py:230, in BaseTrainer.train(self)
#     227         ddp_cleanup(self, str(file))
#     229 else:
# --> 230     self._do_train(world_size)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\engine\trainer.py:461, in BaseTrainer._do_train(self, world_size)
#     459 if self.args.val or final_epoch or self.stopper.possible_stop or self.stop:
#     460     self._clear_memory(threshold=0.5)  # prevent VRAM spike
# --> 461     self.metrics, self.fitness = self.validate()
#     462 self.save_metrics(metrics={**self.label_loss_items(self.tloss), **self.metrics, **self.lr})
#     463 self.stop |= self.stopper(epoch + 1, self.fitness) or final_epoch
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\engine\trainer.py:676, in BaseTrainer.validate(self)
#     668 def validate(self):
#     669     """
#     670     Run validation on test set using self.validator.
#     671
#    (...)    674         fitness (float): Fitness score for the validation.
#     675     """
# --> 676     metrics = self.validator(self)
#     677     fitness = metrics.pop("fitness", -self.loss.detach().cpu().numpy())  # use loss as fitness measure if not found
#     678     if not self.best_fitness or self.best_fitness < fitness:
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\engine\validator.py:210, in BaseValidator.__call__(self, trainer, model)
#     208 # Inference
#     209 with dt[1]:
# --> 210     preds = model(batch["img"], augment=augment)
#     212 # Loss
#     213 with dt[2]:
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\nn\tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\nn\tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\nn\tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:318, in C2f.forward(self, x)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:318, in <genexpr>(.0)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\nn\modules\block.py:495, in Bottleneck.forward(self, x)
#     493 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     494     """Apply bottleneck with optional shortcut connection."""
# --> 495     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\ultralytics\nn\modules\conv.py:81, in Conv.forward(self, x)
#      71 def forward(self, x):
#      72     """
#      73     Apply convolution, batch normalization and activation to input tensor.
#      74
#    (...)     79         (torch.Tensor): Output tensor.
#      80     """
# ---> 81     return self.act(self.bn(self.conv(x)))
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\abhinav.gadge\Documents\KN_Docs_Induction\python_inference_client\.venv\Lib\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
